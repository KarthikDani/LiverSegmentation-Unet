# %% [markdown]
# ### Creating groups of 65 slices

# %%
input_path = "/Users/karthik/liver_segmentation/dicom_file/images"
output_path = "/Users/karthik/liver_segmentation/dicom_groups/images"

# %%
from glob import glob
import shutil
import os
import dicom2nifti

# %%
for patient in sorted(glob(input_path + "/*")):
    patient_name = os.path.basename(os.path.normpath(patient))
    num_folders = len(sorted(glob(patient + "/*"))) // 64
    
    for i in range(num_folders):
        output_path_name = os.path.join(output_path, patient_name + "_" + str(i))
        os.mkdir(output_path_name)
        
        for i, file in enumerate(sorted(glob(patient + "/*"))):
            if i == 64 + 1:
                break
            shutil.move(file, output_path_name)

# %% [markdown]
# #### Incase of random arrangement of files (without using sorted with glob()) this code helped

# %%
# Code to put the files back to their original location.

import os
import shutil

def move_files(input_path, output_path):
    # Iterate through input subfolders
    for input_subfolder in os.listdir(input_path):
        input_subfolder_path = os.path.join(input_path, input_subfolder)

        # Check if it's a directory
        if os.path.isdir(input_subfolder_path):
            # Generate the corresponding output subfolder name
            output_subfolder_name = input_subfolder[:-2]
            output_subfolder_path = os.path.join(output_path, output_subfolder_name)

            # Check if the output subfolder exists
            if os.path.exists(output_subfolder_path):
                # Move all files from input to output subfolder
                for file_name in os.listdir(input_subfolder_path):
                    file_path = os.path.join(input_subfolder_path, file_name)
                    shutil.move(file_path, output_subfolder_path)
                
                # Optionally, you can remove the now-empty input subfolder
                os.rmdir(input_subfolder_path)

input_folder = "/path/to/input"
output_folder = "/path/to/output"

move_files(input_folder, output_folder)

# %% [markdown]
# #### Convert Dicom to Nifties

# %%
input_path_images = "/Users/karthik/liver_segmentation/dicom_groups/images/*"
input_path_labels = "/Users/karthik/liver_segmentation/dicom_groups/labels/*"

output_path_images = "/Users/karthik/liver_segmentation/nifti_files/images"
output_path_labels = "/Users/karthik/liver_segmentation/nifti_files/labels"

images_paths = sorted(glob(input_path_images))
labels_paths = sorted(glob(input_path_labels))

print(images_paths)
print(labels_paths)
# Out:
# ['/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_2', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_3', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_4', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_5', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_6', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_7', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_8', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_100_9', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_2', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_3', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_4', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_5', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_6', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_7', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_8', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_101_9', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_2', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_3', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_4', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_5', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_6', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_7', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_8', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_102_9', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_2', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_3', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_4', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_5', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_6', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_7', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_8', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_103_9', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_10', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_11', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_2', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_3', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_4', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_5', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_6', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_7', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_8', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_104_9', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_105_0', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_105_1', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_105_10', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_105_11', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_105_12', '/Users/karthik/liver_segmentation/dicom_groups/images/liver_ ...
# ['/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_2', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_3', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_4', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_5', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_6', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_7', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_8', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_100_9', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_2', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_3', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_4', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_5', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_6', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_7', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_8', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_101_9', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_2', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_3', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_4', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_5', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_6', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_7', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_8', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_102_9', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_2', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_3', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_4', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_5', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_6', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_7', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_8', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_103_9', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_10', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_11', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_3', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_4', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_5', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_6', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_8', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_104_9', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_0', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_1', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_10', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_11', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_12', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_13', '/Users/karthik/liver_segmentation/dicom_groups/labels/liver_105_14', '/Users/karthik/liver_segmentation/dicom_groups/labels/live ...

# %%
for patient in images_paths:
    patient_name = os.path.basename(os.path.normpath(patient))
    dicom2nifti.dicom_series_to_nifti(patient, os.path.join(output_path_images, patient_name + ".nii.gz"))
    
    # Remove the original DICOM files
    for file in os.listdir(patient):
        file_path = os.path.join(patient, file)
        os.remove(file_path)

# %%
for patient in labels_paths:
    patient_name = os.path.basename(os.path.normpath(patient))
    output_nifti_path = os.path.join(output_path_labels, patient_name + ".nii.gz")

    try:
        # Convert DICOM to NIfTI
        dicom2nifti.dicom_series_to_nifti(patient, output_nifti_path)

        # Remove the original DICOM files
        for file in os.listdir(patient):
            file_path = os.path.join(patient, file)
            os.remove(file_path)

        # Optionally, you can remove the now-empty patient folder
        
        os.rmdir(patient)

    except Exception as e:
        print(f"Error processing {patient}: {str(e)}")

# %% [markdown]
# ##### Find empty labels

# %%
import os
import nibabel as nib
import numpy as np
from glob import glob

input_nifti_file_path = "/Users/karthik/liver_segmentation/nifti_files/labels/*"
labels = sorted(glob(input_nifti_file_path))

print(labels)

empty_labels = []
for patient in labels:
    nifti_file = nib.load(patient)
    fdata = nifti_file.get_fdata()
    np_unique = np.unique(fdata)
    if len(np_unique) == 1:
        empty_labels.append(patient)

print(sorted(empty_labels))

# Delete files in empty_labels
for file_path in empty_labels:
    try:
        os.remove(file_path)
        print(f"Deleted file: {file_path}")
    except Exception as e:
        print(f"Error deleting file {file_path}: {str(e)}")
# Out:
# ['/Users/karthik/liver_segmentation/nifti_files/labels/liver_0_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_104_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_104_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_106_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_106_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_107_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_107_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_108_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_109_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_109_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_109_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_4.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_6.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_110_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_110_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_111_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_111_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_111_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_112_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_112_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_112_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_113_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_114_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_115_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_117_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_4.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_4.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_6.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_4.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_6.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_2.nii.gz', '/Users/karthik/liver_segmentation/nifti ...
# ['/Users/karthik/liver_segmentation/nifti_files/labels/liver_104_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_104_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_106_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_106_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_107_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_107_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_108_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_109_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_109_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_10_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_110_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_110_7.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_111_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_111_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_112_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_112_8.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_113_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_114_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_115_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_117_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_118_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_119_6.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_11_3.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_120_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_121_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_121_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_121_2.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_121_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_121_6.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_122_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_122_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_122_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_123_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_123_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_123_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_124_0.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_124_1.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_124_5.nii.gz', '/Users/karthik/liver_segmentation/nifti_files/labels/liver_125_0.nii.gz', '/Users/karthik/liver_segmentati ...
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_104_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_104_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_106_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_106_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_107_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_107_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_108_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_109_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_109_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_10_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_10_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_10_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_10_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_110_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_110_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_111_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_111_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_112_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_112_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_113_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_114_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_115_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_117_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_118_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_118_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_118_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_118_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_119_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_119_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_119_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_119_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_11_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_11_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_11_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_11_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_120_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_120_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_120_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_121_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_121_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_121_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_121_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_121_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_122_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_122_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_122_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_123_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_123_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_123_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_124_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_124_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_124_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_125_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_125_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_125_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_126_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_126_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_126_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_128_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_128_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_128_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_128_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_12_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_12_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_12_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_12_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_130_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_130_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_130_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_130_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_130_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_13_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_14_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_15_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_15_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_15_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_15_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_15_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_16_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_17_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_17_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_18_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_19_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_19_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_19_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_19_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_20_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_20_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_20_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_20_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_20_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_21_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_21_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_21_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_21_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_22_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_23_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_23_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_23_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_23_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_24_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_24_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_25_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_25_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_25_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_25_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_25_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_2_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_2_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_2_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_2_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_2_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_3_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_3_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_3_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_3_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_47_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_48_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_49_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_4_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_50_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_51_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_52_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_55_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_56_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_56_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_57_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_57_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_57_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_58_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_59_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_59_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_5_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_5_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_5_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_5_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_60_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_60_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_61_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_62_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_64_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_65_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_65_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_65_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_65_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_67_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_68_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_68_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_69_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_69_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_6_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_6_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_6_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_6_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_70_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_70_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_70_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_74_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_76_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_78_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_79_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_7_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_7_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_7_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_7_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_80_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_81_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_81_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_81_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_82_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_82_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_82_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_82_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_84_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_85_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_85_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_85_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_85_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_85_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_86_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_86_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_86_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_86_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_86_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_88_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_88_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_89_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_89_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_8_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_8_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_8_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_8_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_8_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_90_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_90_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_91_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_91_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_92_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_93_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_95_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_96_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_97_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_98_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_98_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_98_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_98_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_98_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_99_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_99_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_99_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_99_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_99_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_9_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_9_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_9_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_9_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_9_4.nii.gz

# %%
import os

folder_path = "/Users/karthik/liver_segmentation/nifti_files/labels"

# Function to recursively delete empty folders
def delete_empty_folders(directory):
    for root, dirs, files in os.walk(directory, topdown=False):
        for folder in dirs:
            folder_path = os.path.join(root, folder)
            if not os.listdir(folder_path):
                try:
                    os.rmdir(folder_path)
                    print(f"Deleted empty folder: {folder_path}")
                except Exception as e:
                    print(f"Error deleting folder {folder_path}: {str(e)}")

# Call the function to delete empty folders
delete_empty_folders(folder_path)

# %%
import os

images_folder = "/Users/karthik/liver_segmentation/nifti_files/images"
labels_folder = "/Users/karthik/liver_segmentation/nifti_files/labels"

# Get the list of files in both folders
images_files = os.listdir(images_folder)
labels_files = os.listdir(labels_folder)

# Iterate through files in the "images" folder
for image_file in images_files:
    # Check if there is a matching file in the "labels" folder
    if image_file not in labels_files:
        image_file_path = os.path.join(images_folder, image_file)
        try:
            # Delete the file in the "images" folder
            os.remove(image_file_path)
            print(f"Deleted file: {image_file_path}")
        except Exception as e:
            print(f"Error deleting file {image_file_path}: {str(e)}")
# Out:
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_5_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_12_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_70_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_24_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_25_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_65_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_52_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_121_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_15_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_118_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_119_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_2_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_19_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_85_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_67_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_130_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_123_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_122_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_10_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_11_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_124_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_125_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_82_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_9_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_8_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_59_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_58_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_6_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_7_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_130_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_98_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_99_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_19_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_6_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_7_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_14.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_13.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_82_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_10_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_11_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_25_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_81_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_70_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_12_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_126_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_5_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_118_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_119_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_65_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_9_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_8_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_56_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_57_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_98_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_99_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_69_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_21_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_20_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_85_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_76_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_15_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_121_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_120_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_23_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_86_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_3_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_2_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_49_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_48_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_128_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_119_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_3_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_2_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_23_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_22_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_86_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_121_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_55_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_25_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_128_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_124_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_125_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_9_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_60_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_61_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_8_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_21_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_130_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_20_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_85_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_123_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_122_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_68_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_98_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_99_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_82_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_125_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_124_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_13.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_11_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_10_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_7_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_6_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_59_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_19_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_130_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_15_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_65_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_79_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_78_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_5_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_81_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_25_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_24_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_47_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_12_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_119_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_118_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_64_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_86_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_65_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_120_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_121_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_126_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_70_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_12_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_81_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_80_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_25_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_5_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_7_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_6_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_11_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_10_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_82_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_13.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_130_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_20_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_50_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_51_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_19_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_128_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_13_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_126_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_62_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_86_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_23_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_120_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_121_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_15_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_2_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_3_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_118_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_69_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_68_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_99_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_98_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_85_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_20_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_21_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_57_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_56_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_8_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_9_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_13.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_122_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_123_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_74_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_97_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_16_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_106_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_17_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_107_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_114_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_84_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_85_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_115_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_20_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_12.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_21_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_109_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_108_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_18_6.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_99_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_98_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_13.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_14.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_112_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_83_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_8_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_9_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_60_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_91_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_90_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_101_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_100_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_57_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_11.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_103_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_102_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_93_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_92_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_127_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_4_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_110_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_128_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_111_8.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_2_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_3_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_96_10.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_88_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_89_9.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_104_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_14_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_105_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_15_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_94_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_95_7.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_86_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_87_2.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_116_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_117_0.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_23_1.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/images/liver_113_12.nii.gz

# %%
import os

images_folder = "/Users/karthik/liver_segmentation/nifti_files/images"
labels_folder = "/Users/karthik/liver_segmentation/nifti_files/labels"

# Get the list of files in both folders
images_files = set(os.listdir(images_folder))
labels_files = os.listdir(labels_folder)

# Iterate through files in the "labels" folder
for label_file in labels_files:
    # Check if there is a matching file in the "images" folder
    if label_file not in images_files:
        label_file_path = os.path.join(labels_folder, label_file)
        try:
            # Delete the file in the "labels" folder
            os.remove(label_file_path)
            print(f"Deleted file: {label_file_path}")
        except Exception as e:
            print(f"Error deleting file {label_file_path}: {str(e)}")
# Out:
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_3.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_5.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_4.nii.gz
# Deleted file: /Users/karthik/liver_segmentation/nifti_files/labels/liver_26_6.nii.gz

# %%
import os
import random
import shutil

# Set the paths to your images and labels folders
images_folder = "/Users/karthik/liver_segmentation/nifti_files/images"
labels_folder = "/Users/karthik/liver_segmentation/nifti_files/labels"
test_images_folder = "/Users/karthik/liver_segmentation/nifti_files/TestImages"
test_labels_folder = "/Users/karthik/liver_segmentation/nifti_files/TestLabels"

# Ensure that the test folders exist, create them if not
os.makedirs(test_images_folder, exist_ok=True)
os.makedirs(test_labels_folder, exist_ok=True)

# Get the list of file names in the images folder
image_files = os.listdir(images_folder)

# Shuffle the file names
random.shuffle(image_files)

# Calculate the number of files to move (10% of the total)
num_files_to_move = int(0.1 * len(image_files))

# Get the first num_files_to_move file names
files_to_move = image_files[:num_files_to_move]

# Move the selected image files to the TestImages folder
for file_name in files_to_move:
    source_path_image = os.path.join(images_folder, file_name)
    dest_path_image = os.path.join(test_images_folder, file_name)
    shutil.move(source_path_image, dest_path_image)

    # Check if corresponding label file exists and move it to TestLabels
    corresponding_label_file = os.path.join(labels_folder, file_name)
    if os.path.exists(corresponding_label_file):
        dest_path_label = os.path.join(test_labels_folder, file_name)
        shutil.move(corresponding_label_file, dest_path_label)
